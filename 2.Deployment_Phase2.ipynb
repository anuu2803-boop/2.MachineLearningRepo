# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_model_mutiple_linear.sav",'rb'))

# %%
result=loaded_model.predict([[1.234,345.6,345.8,0,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[42730.80729805]])
