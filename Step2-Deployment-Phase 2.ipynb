# %%
import pickle # importing pickle library

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb')) #loading the file binaries in loaded_model variable

# %%
result=loaded_model.predict([[15]])# assigning the result variable with the input of 15
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[164431.80347965]])
